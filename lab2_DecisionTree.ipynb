# %%
# imported numpy to perform calculations
import numpy as np
# imported pandas to import the data set -> csv file 
import pandas as pd

# %%
# loading the iris dataset csv file
# skiprows is used to skip the 1st row of the dataset
data = pd.read_csv('iris_dataset.csv', skiprows=1,header=None)
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Split the dataset into input features (x)

# extracting the values from 1st column or index "0"
# Converting dataset into a numpy array 

x = data.iloc[:,:-1].values
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# Split the dataset into target variable (y)

# extracting the values from 1st column or index "0"
# Converting dataset into a numpy array 

y1 = data.iloc[:,-1].values
y1
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %%
# we are reshping by giving "-1" as 1st argument -> this indicates to calculate the dimension of the rows by the model automatically
# "1" as 2nd argument -> this indicates column dimension is 1

y = y1.reshape(-1,1)
y
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
from sklearn.model_selection import train_test_split
# Splitting the dataset into training and test sets
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=41)

# we will have different classifiers in sklearn.tree
# we have imported tree from sklearn to get decision tree classifier
from sklearn import tree

# Fit a decision tree classifier to the training set
# max_depth = 3 in order to limit upto three layers
# "entropy" is the method of approach to find Decision value
classifier = tree.DecisionTreeClassifier(min_samples_split=3,max_depth=3,criterion="entropy")

# fit is used to train the model
classifier.fit(xtrain,ytrain)

# score is used to find the accuracy of the classifier on the test set
score = classifier.score(xtest,ytest)
score
# Out:
# 0.9111111111111111

# %%
# predict is used to make predictions on the test set to get predicted y values
y_pred = classifier.predict(xtest)
y_pred
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica'], dtype=object)

# %%
y_pred1 = y_pred.reshape(-1,1)
y_pred1
# Out:
# array([['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
# ...

# %%
from sklearn.metrics import accuracy_score
# accuracy_score is imported to show the accuracy of the predictions
accuracy = accuracy_score(ytest, y_pred)
print(accuracy)
# Out:
# 0.9111111111111111

# %%
# imported matplotlib to visualize the data
import matplotlib.pyplot as plt
# plot_tree(classifier, filled=True) is used to plot the decision tree with filled nodes
tree.plot_tree(classifier,max_depth=3,filled=True)
# plt.show() to display the plot
plt.show()
